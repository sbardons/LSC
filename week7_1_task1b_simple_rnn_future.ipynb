# %% [markdown]
# <a href="https://colab.research.google.com/github/UofGAnalytics/BOLDscalable/blob/master/coursematerial/week7/simple_rnn_future.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Week 7 Task 1.
# Implement the RNN shown in te eprevious  example
#
# Learning it kind of time step process..
#  Change te epredictabiliye and see how hee
# accuracy of the predictions is altered.

# %%
import numpy as np
import tensorflow as tf
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd

np.random.seed(20)

# %% [markdown]
# ## Create some random data that is somewhat predictable

# %%
# 442 data points with some autocorrelation:
#difference between each value and the next value weighted sum of a previous step 
#and a current random noraml variable

N=442

# weight is how much previous steps affect the current step
weight = 0.30 # original
#weight = 0.99 # highly correlated
#weight = 0 # unpredictable
ts = np.zeros(N)


# first step is a random jump
ts[1] = ts[0]+np.random.normal()

for i in range(2,N):
    rn = np.random.normal()
    prev_step = ts[i-1]-ts[i-2]
    # each step is a combination of the current random jump and the previous step
    ts[i] = ts[i-1]+(weight*prev_step) + (1.0-weight)*rn

# %% [markdown]
# ## Plot the generated data

# %%
plt.figure(figsize=(11,4))
plt.subplot(121)
plt.plot(ts)
plt.plot(np.arange(90,96),ts[90:96], "b-", linewidth=3, label="A training instance")
plt.title("Time series", fontsize=14)


plt.subplot(122)
plt.title("Example training instance", fontsize=14)
plt.plot(np.arange(90,95),ts[90:95], "bo-", markersize=8, label="training")
plt.plot(np.arange(95,96),ts[95:96], "bo", markersize=10, label="target", markerfacecolor='red')
plt.legend(loc="best")

plt.show()
# we are going to pass 5 of these values in order and going to predict what's going to come next

# %% [markdown]
# ## Set parameters and process the data

# %%
n_window = 5   # size of the sequence to use for prediction  #CHANGED from 5 to 10!
n_input =  1   # dimension of the input data
n_output = 1   # dimension of the prediction
size_train = 401 # how much training data to use, keep one for the final target
n_neurons = 32  # number of neurons in each cell 

#in more complicated tasks both input and output coudl be multi-dimensional

# Split the data into training and test data
train = ts[:size_train]
test = ts[size_train:]

# reshape into batches of length given by window
X_batch = train[:-1].reshape(-1, n_window, n_input)
Y_batch = train[n_window::n_window].reshape(-1, n_input)

X_test = test[:-1].reshape(-1, n_window, n_input)
Y_test = test[n_window::n_window].reshape(-1, n_input)

# %%
print(X_batch.shape, Y_batch.shape) #80 sequences, each of 5 values one dimensional - 80 samples corresponding to the target
print(X_test.shape, Y_test.shape) #same bu far fewer points
# Out:
# (80, 5, 1) (80, 1)
# (8, 5, 1) (8, 1)

# %% [markdown]
# ## Plot some example training data

# %%
i=60
plt.plot(X_batch[i], "bo-", markersize=8, label="training")
plt.plot([10],Y_batch[i], "bo", markersize=10, label="target", markerfacecolor='red')
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ## Create the RNN

# %%
rnn_cell = tf.keras.layers.SimpleRNNCell(units=n_neurons, activation=tf.nn.relu)   
rnn_layer = tf.keras.layers.RNN(rnn_cell)
prediction_layer = tf.keras.layers.Dense(1)

def predict(x):

    x = rnn_layer(x)
    prediction = prediction_layer(x)

    return prediction

def loss(x,y):
    prediction = predict(x)
    loss = tf.reduce_mean(tf.square(prediction - y))  
    return loss

# %% [markdown]
# ## Set-up the training

# %%
lr = 0.01
train_steps = 2000
# we'll use the Adam optimizer instead of gradient descent.
optimizer = tf.optimizers.Adam(lr)

# %% [markdown]
# ## Train the model

# %%
for i in range(train_steps):
    with tf.GradientTape() as tape:
        current_loss = loss(X_batch,Y_batch)
        gradients = tape.gradient(current_loss, tape.watched_variables())
        optimizer.apply_gradients(zip(gradients, tape.watched_variables()))
        if i%100 == 0:
            print('Training Step:' + str(i) + ' Loss = ' + str(current_loss))
y_pred = predict(X_test)
# Out:
# 2023-06-19 18:52:35.572328: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-19 18:52:36.600335: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14626 MB memory:  -> device: 0, name: Tesla V100-PCIE-16GB, pci bus id: 0001:00:00.0, compute capability: 7.0
# Training Step:0 Loss = tf.Tensor(76.68734, shape=(), dtype=float32)
# Training Step:100 Loss = tf.Tensor(0.44545278, shape=(), dtype=float32)
# Training Step:200 Loss = tf.Tensor(0.2987737, shape=(), dtype=float32)
# Training Step:300 Loss = tf.Tensor(0.19116218, shape=(), dtype=float32)
# Training Step:400 Loss = tf.Tensor(0.16876772, shape=(), dtype=float32)
# Training Step:500 Loss = tf.Tensor(0.14662895, shape=(), dtype=float32)
# Training Step:600 Loss = tf.Tensor(0.13334928, shape=(), dtype=float32)
# Training Step:700 Loss = tf.Tensor(0.1237572, shape=(), dtype=float32)
# Training Step:800 Loss = tf.Tensor(0.1186445, shape=(), dtype=float32)
# Training Step:900 Loss = tf.Tensor(0.1015176, shape=(), dtype=float32)
# Training Step:1000 Loss = tf.Tensor(0.10056913, shape=(), dtype=float32)
# Training Step:1100 Loss = tf.Tensor(0.10359734, shape=(), dtype=float32)
# Training Step:1200 Loss = tf.Tensor(0.083624765, shape=(), dtype=float32)
# Training Step:1300 Loss = tf.Tensor(0.12290318, shape=(), dtype=float32)
# Training Step:1400 Loss = tf.Tensor(0.0785013, shape=(), dtype=float32)
# Training Step:1500 Loss = tf.Tensor(0.06913459, shape=(), dtype=float32)
# Training Step:1600 Loss = tf.Tensor(0.06667385, shape=(), dtype=float32)
# Training Step:1700 Loss = tf.Tensor(0.05635085, shape=(), dtype=float32)
# Training Step:1800 Loss = tf.Tensor(0.05148672, shape=(), dtype=float32)
# Training Step:1900 Loss = tf.Tensor(0.05033865, shape=(), dtype=float32)

# %% [markdown]
# reduced the weight: loss is higher

# %% [markdown]
# ## Plot the predictions

# %%
X_test  #(8, 5, 1)
# Out:
# array([[[14.33747673],
#         [14.0339695 ],
#         [14.1498278 ],
#         [13.89599698],
#         [13.49075496]],
#
#        [[14.7305056 ],
#         [15.55674931],
#         [16.6231836 ],
#         [17.04499921],
#         [18.1084658 ]],
#
#        [[17.85342136],
#         [17.40996737],
#         [16.07454831],
#         [15.57944589],
#         [16.29210989]],
#
#        [[15.60030628],
#         [14.33647828],
#         [14.33928879],
#         [13.00263628],
#         [12.91343939]],
#
#        [[12.35681179],
#         [11.59125114],
#         [11.28874272],
#         [11.28606182],
#         [11.14469856]],
#
#        [[10.72814635],
#         [10.06540438],
#         [11.15793097],
#         [10.66176922],
#         [10.18843862]],
#
#        [[10.06380361],
#         [10.3530689 ],
#         [10.68734858],
#         [11.33972754],
#         [11.0733806 ]],
#
#        [[10.9997907 ],
#         [ 9.83961643],
#         [ 9.63967893],
#         [ 9.125187  ],
#         [ 9.81018475]]])

# %%
X_test[0,:,0]
# Out:
# array([14.33747673, 14.0339695 , 14.1498278 , 13.89599698, 13.49075496])

# %%
plt.title("Forecast vs Actual", fontsize=14)

for i in range(8):
    #plt.plot(np.append(X_test[i,:,0],Y_test[i]), "bo-", markersize=5, label="training")
    plt.plot(X_test[i,:,0], "bo-", markersize=5, label="training")
    plt.plot([5],Y_test[i], "bo", markersize=8, label="actual")
    plt.plot([5],y_pred[i], "bo", markersize=10, label="forecast", markerfacecolor='red')
    plt.legend(loc="best")

    plt.show()

# %% [markdown]
# We can increase the predictability of the time series by altering the weight parameter
# in the random data creation cell
