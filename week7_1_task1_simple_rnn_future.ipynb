# %% [markdown]
# <a href="https://colab.research.google.com/github/UofGAnalytics/BOLDscalable/blob/master/coursematerial/week7/simple_rnn_future.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Week 7 Task 1.
# Implement the RNN shown in theprevious  example. Change the length of the sequence and see how the
# accuracy of the predictions is altered.

# %%
import numpy as np
import tensorflow as tf
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd

np.random.seed(20)

# %% [markdown]
# ## Create some random data that is somewhat predictable

# %%
# 442 data points with some autocorrelation:
#difference between each value and the next value weighted sum of a previous step 
#and a current random noraml variable

N=442

# weight is how much previous steps affect the current step
weight = 0.60 # original
#weight = 0.99 # highly correlated
#weight = 0 # unpredictable
ts = np.zeros(N)


# first step is a random jump
ts[1] = ts[0]+np.random.normal()

for i in range(2,N):
    rn = np.random.normal()
    prev_step = ts[i-1]-ts[i-2]
    # each step is a combination of the current random jump and the previous step
    ts[i] = ts[i-1]+(weight*prev_step) + (1.0-weight)*rn

# %% [markdown]
# ## Plot the generated data

# %%
plt.figure(figsize=(11,4))
plt.subplot(121)
plt.plot(ts)
plt.plot(np.arange(90,96),ts[90:96], "b-", linewidth=3, label="A training instance")
plt.title("Time series", fontsize=14)


plt.subplot(122)
plt.title("Example training instance", fontsize=14)
plt.plot(np.arange(90,95),ts[90:95], "bo-", markersize=8, label="training")
plt.plot(np.arange(95,96),ts[95:96], "bo", markersize=10, label="target", markerfacecolor='red')
plt.legend(loc="best")

plt.show()
# we are going to pass 5 of these values in order and going to predict what's going to come next

# %% [markdown]
# ## Set parameters and process the data

# %%
n_window = 10   # size of the sequence to use for prediction  #CHANGED from 5 to 10!
n_input =  1   # dimension of the input data
n_output = 1   # dimension of the prediction
size_train = 401 # how much training data to use, keep one for the final target
n_neurons = 32  # number of neurons in each cell 

#in more complicated tasks both input and output coudl be multi-dimensional

# Split the data into training and test data
train = ts[:size_train]
test = ts[size_train:]

# reshape into batches of length given by window
X_batch = train[:-1].reshape(-1, n_window, n_input)
Y_batch = train[n_window::n_window].reshape(-1, n_input)

X_test = test[:-1].reshape(-1, n_window, n_input)
Y_test = test[n_window::n_window].reshape(-1, n_input)

# %%
print(X_batch.shape, Y_batch.shape) #80 sequences, each of 5 values one dimensional - 80 samples corresponding to the target
print(X_test.shape, Y_test.shape) #same bu far fewer points
# Out:
# (40, 10, 1) (40, 1)
# (4, 10, 1) (4, 1)

# %% [markdown]
# ## Plot some example training data

# %%
i=4
plt.plot(X_batch[i], "bo-", markersize=8, label="training")
plt.plot([10],Y_batch[i], "bo", markersize=10, label="target", markerfacecolor='red')
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ## Create the RNN

# %%
rnn_cell = tf.keras.layers.SimpleRNNCell(units=n_neurons, activation=tf.nn.relu)   
rnn_layer = tf.keras.layers.RNN(rnn_cell)
prediction_layer = tf.keras.layers.Dense(1)

def predict(x):

    x = rnn_layer(x)
    prediction = prediction_layer(x)

    return prediction

def loss(x,y):
    prediction = predict(x)
    loss = tf.reduce_mean(tf.square(prediction - y))  
    return loss

# %% [markdown]
# ## Set-up the training

# %%
lr = 0.01
train_steps = 2000
# we'll use the Adam optimizer instead of gradient descent.
optimizer = tf.optimizers.Adam(lr)

# %% [markdown]
# ## Train the model

# %%
for i in range(train_steps):
    with tf.GradientTape() as tape:
        current_loss = loss(X_batch,Y_batch)
        gradients = tape.gradient(current_loss, tape.watched_variables())
        optimizer.apply_gradients(zip(gradients, tape.watched_variables()))
        if i%100 == 0:
            print('Training Step:' + str(i) + ' Loss = ' + str(current_loss))
y_pred = predict(X_test)
# Out:
# 2023-06-19 15:19:27.027086: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-19 15:19:27.625768: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13 MB memory:  -> device: 0, name: Tesla M60, pci bus id: 0001:00:00.0, compute capability: 5.2
# Training Step:0 Loss = tf.Tensor(54.85099, shape=(), dtype=float32)
# Training Step:100 Loss = tf.Tensor(0.12348248, shape=(), dtype=float32)
# Training Step:200 Loss = tf.Tensor(0.035298977, shape=(), dtype=float32)
# Training Step:300 Loss = tf.Tensor(0.014031027, shape=(), dtype=float32)
# Training Step:400 Loss = tf.Tensor(0.010599929, shape=(), dtype=float32)
# Training Step:500 Loss = tf.Tensor(0.004133239, shape=(), dtype=float32)
# Training Step:600 Loss = tf.Tensor(0.0011803822, shape=(), dtype=float32)
# Training Step:700 Loss = tf.Tensor(0.00055785256, shape=(), dtype=float32)
# Training Step:800 Loss = tf.Tensor(0.00014688117, shape=(), dtype=float32)
# Training Step:900 Loss = tf.Tensor(7.378165e-05, shape=(), dtype=float32)
# Training Step:1000 Loss = tf.Tensor(5.1034294e-05, shape=(), dtype=float32)
# Training Step:1100 Loss = tf.Tensor(0.0032246918, shape=(), dtype=float32)
# Training Step:1200 Loss = tf.Tensor(0.0023219697, shape=(), dtype=float32)
# Training Step:1300 Loss = tf.Tensor(0.0008210183, shape=(), dtype=float32)
# Training Step:1400 Loss = tf.Tensor(0.00036759116, shape=(), dtype=float32)
# Training Step:1500 Loss = tf.Tensor(0.00035849304, shape=(), dtype=float32)
# Training Step:1600 Loss = tf.Tensor(0.00018690445, shape=(), dtype=float32)
# Training Step:1700 Loss = tf.Tensor(6.907592e-05, shape=(), dtype=float32)
# Training Step:1800 Loss = tf.Tensor(0.00044413097, shape=(), dtype=float32)
# Training Step:1900 Loss = tf.Tensor(0.0003181574, shape=(), dtype=float32)

# %% [markdown]
# lower error then before

# %% [markdown]
# ## Plot the predictions

# %%
X_test  #(4, 10, 1)  so the rnage in the loop is upt to 4!
# Out:
# array([[[15.5642969 ],
#         [15.27894747],
#         [15.22597235],
#         [15.02927968],
#         [14.72321107],
#         [15.3174689 ],
#         [15.93363418],
#         [16.77108259],
#         [17.33177182],
#         [18.2035693 ]],
#
#        [[18.39859955],
#         [18.30593733],
#         [17.56326407],
#         [17.06367343],
#         [17.25603032],
#         [16.85395713],
#         [16.0091207 ],
#         [15.72048107],
#         [14.78301406],
#         [14.39870463]],
#
#        [[13.86533695],
#         [13.20327499],
#         [12.76441483],
#         [12.55142538],
#         [12.34331228],
#         [12.0046483 ],
#         [11.49414915],
#         [11.92576349],
#         [11.71392082],
#         [11.40139688]],
#
#        [[11.2238049 ],
#         [11.30391017],
#         [11.49340196],
#         [11.92257992],
#         [11.91605205],
#         [11.91574343],
#         [11.26521695],
#         [10.95953808],
#         [10.51641036],
#         [10.73015964]]])

# %%
X_test[0,:,0]
# Out:
# array([15.5642969 , 15.27894747, 15.22597235, 15.02927968, 14.72321107,
#        15.3174689 , 15.93363418, 16.77108259, 17.33177182, 18.2035693 ])

# %%
plt.title("Forecast vs Actual", fontsize=14)

for i in range(4):
    #plt.plot(np.append(X_test[i,:,0],Y_test[i]), "bo-", markersize=5, label="training")
    plt.plot(X_test[i,:,0], "bo-", markersize=5, label="training")
    plt.plot([10],Y_test[i], "bo", markersize=8, label="actual")
    plt.plot([10],y_pred[i], "bo", markersize=10, label="forecast", markerfacecolor='red')
    plt.legend(loc="best")

    plt.show()
