# %%
# !git config --global credential.helper 'store --file ~credentials'

# %%
#download files expecially if large
# in colab this is not persistent
# !wget url address

# %%
#list of packages#
# colab would not use conda
! conda list
# Out:
# # packages in environment at /opt/conda:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                 conda_forge    conda-forge
# _openmp_mutex             4.5                  2_kmp_llvm    conda-forge
# absl-py                   1.4.0                    pypi_0    pypi
# aiofiles                  22.1.0             pyhd8ed1ab_0    conda-forge
# aiohttp                   3.8.4                    pypi_0    pypi
# aiosignal                 1.3.1                    pypi_0    pypi
# aiosqlite                 0.18.0             pyhd8ed1ab_0    conda-forge
# alembic                   1.10.4             pyhd8ed1ab_0    conda-forge
# altair                    4.2.2              pyhd8ed1ab_0    conda-forge
# anyio                     3.6.2              pyhd8ed1ab_0    conda-forge
# aom                       3.5.0                h27087fc_0    conda-forge
# argon2-cffi               21.3.0             pyhd8ed1ab_0    conda-forge
# ...

# %%
# to install packages
! pip install arviz  #this is for mcm sampling
import arviz
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 31.6 MB/s eta 0:00:0000:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 973.1/973.1 kB 38.7 MB/s eta 0:00:00
# ...

# %%
# !nvidia-smi  # will tell me what kind of GPU I have
#the ram is the one that tells us the powet of the GPU
# Out:
# Tue May 16 21:15:15 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000001:00:00.0 Off |                  Off |
# | N/A   44C    P0    27W /  70W |  15095MiB / 16384MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# other way to see if GPU is present, but less information given
import tensorflow as tf

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
